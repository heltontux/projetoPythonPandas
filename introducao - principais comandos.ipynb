# %%
#importando a biblioteca pandas
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/DIO/Cusro_Python_Pandas_Digital_Innovation-master/datasets/Gapminder.csv",error_bad_lines=False, sep=';')

# %%
# podemos ignorar as linhas com problemas com a opção error_bad_lines = False.
# podemos verificar todos os parâmetros colocando virgula após as aspas e dando Enter.

# %%
# visualizando as 5 primeiras linhas
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# Vamos modificar o nome das colunas. 
df.rename(columns={'country':'Pais', 'continent':'Continente', 'year':'Ano', 'lifeExp':'Expectativa de vida', 'pop':'População', 'gdpPercap': 'PIB'})
# Out:
#              Pais Continente   Ano  Expectativa de vida  População         PIB
# 0     Afghanistan       Asia  1952               28.801    8425333  779.445314
# 1     Afghanistan       Asia  1957               30.332    9240934  820.853030
# 2     Afghanistan       Asia  1962               31.997   10267083  853.100710
# 3     Afghanistan       Asia  1967               34.020   11537966  836.197138
# 4     Afghanistan       Asia  1972               36.088   13079460  739.981106
# ...           ...        ...   ...                  ...        ...         ...
# 3307     Zimbabwe     Africa  1987               62.351    9216418  706.157306
# 3308     Zimbabwe     Africa  1992               60.377   10704340  693.420786
# 3309     Zimbabwe     Africa  1997               46.809   11404948  792.449960
# 3310     Zimbabwe     Africa  2002               39.989   11926563  672.038623
# 3311     Zimbabwe     Africa  2007               43.487   12311143  469.709298
#
# [3312 rows x 6 columns]

# %%
# Gravando a modificação no Data Frame
df = df.rename(columns={'country':'Pais', 'continent':'Continente', 'year':'Ano', 'lifeExp':'Expectativa de vida', 'pop':'População', 'gdpPercap': 'PIB'})

# %% [markdown]
# visualizando as 5 primeiras linhas

# %%
df.head()
# Out:
#           Pais Continente   Ano  Expectativa de vida  População         PIB
# 0  Afghanistan       Asia  1952               28.801    8425333  779.445314
# 1  Afghanistan       Asia  1957               30.332    9240934  820.853030
# 2  Afghanistan       Asia  1962               31.997   10267083  853.100710
# 3  Afghanistan       Asia  1967               34.020   11537966  836.197138
# 4  Afghanistan       Asia  1972               36.088   13079460  739.981106

# %% [markdown]
# Visualizando as 5 ultimas linhas

# %%
df.tail()
# Out:
#           Pais Continente   Ano  Expectativa de vida  População         PIB
# 3307  Zimbabwe     Africa  1987               62.351    9216418  706.157306
# 3308  Zimbabwe     Africa  1992               60.377   10704340  693.420786
# 3309  Zimbabwe     Africa  1997               46.809   11404948  792.449960
# 3310  Zimbabwe     Africa  2002               39.989   11926563  672.038623
# 3311  Zimbabwe     Africa  2007               43.487   12311143  469.709298

# %% [markdown]
# Se quiser visualizar um numero diferente de linhas basta colocar entre os parentes, como em:
# # df.head(10)
# Visualiza as 10 primeoras linhas
#
# #df.tail(15)
# Visualiza as 15 ultimas linhas

# %%
#Total de linhas e colunas
df.shape
# Out:
# (3312, 6)

# %%
#Cabeçalho das colunas
df.columns
# Out:
# Index(['Pais', 'Continente', 'Ano', 'Expectativa de vida', 'População', 'PIB'], dtype='object')

# %%
#Tipo de dados nas colunas
df.dtypes
# Out:
# Pais                    object
# Continente              object
# Ano                      int64
# Expectativa de vida    float64
# População                int64
# PIB                    float64
# dtype: object

# %% [markdown]
# O tipo object é o mesmo que string no data frame

# %%
#Informações estatísticas
df.describe()
# Out:
#                Ano  Expectativa de vida     População            PIB
# count  3312.000000          3312.000000  3.312000e+03    3312.000000
# mean   1980.301630            65.246871  3.161489e+07   11317.115805
# std      16.927294            11.768412  1.041193e+08   11369.142739
# min    1950.000000            23.599000  5.941200e+04     241.165877
# 25%    1967.000000            58.337500  2.678572e+06    2514.625266
# 50%    1982.000000            69.610000  7.557218e+06    7838.505123
# 75%    1996.000000            73.657750  1.958522e+07   17357.879170
# max    2007.000000            82.670000  1.318683e+09  113523.132900

# %% [markdown]
# # count --> total de linhas
# # mean ---> media
# # std ----> desvio padrao
# # min ----> minimo
# # 25% ----> primeiro quartil
# # 50% ----> segundo  quartil (mediana)
# # 75% ----> terceiro quartil
# # max ----> maximo

# %%
# Mostrar as entradas do campo de forma unica
df['Continente'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
# Propriedade "loc" fitra um nome
Oceania = df.loc[df['Continente'] == 'Oceania']
Oceania.head()
# Out:
#      Pais Continente   Ano  Expectativa de vida  População          PIB
# 975  Fiji    Oceania  1962               56.494     421869  2039.393277
# 976  Fiji    Oceania  1967               58.607     485000  2170.073285
# 977  Fiji    Oceania  1972               60.642     544000  2797.759484
# 978  Fiji    Oceania  1977               62.669     599339  3182.569600
# 979  Fiji    Oceania  1982               64.683     658906  3209.257468

# %%
# Numero de países em um continente
# Agrupar ocorrencias de Pais em Continente:
# unique => nome da ocorrencia unica
# numique => numeric unique: numero de ocorrencias
df.groupby('Continente')['Pais'].unique()
# Out:
# Continente
# Africa      [Algeria, Angola, Benin, Botswana, Burkina Fas...
# Americas    [Argentina, Bolivia, Brazil, Chile, Colombia, ...
# Asia        [Afghanistan, Azerbaijan, Bahrain, Bangladesh,...
# Europe      [Albania, Austria, Belgium, Bosnia and Herzego...
# FSU         [Belarus, Kazakhstan, Latvia, Lithuania, Russi...
# Oceania                  [Fiji, New Zealand, Solomon Islands]
# Name: Pais, dtype: object

# %%
df.groupby('Continente')['Pais'].nunique()
# Out:
# Continente
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: Pais, dtype: int64

# %%
# Media de expectativa de vida por ano
df.groupby("Ano")["Expectativa de vida"].mean()
# Out:
# Ano
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283437
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...

# %%
# Média do PIB
df["PIB"].mean()
# Out:
# 11317.115804696637

# %%
# Soma do PIB 
df['PIB'].sum()
# Out:
# 37482287.5451553
